# %%
import sys
sys.path.append('..')
import os

from utils.constants import *
from utils.file_readers import *
from utils.data_exploration import *
from utils.signal_processing import *
from utils.sliding_window import *
from utils.stand_norm import *
from utils.one_vs_all_training import *
# Out:
# Using TensorFlow backend.

# %%
activity_names = get_activity_name_dict()
one_vs_all_activity = activity_names['Step ups']

# %%
experiment_name = "15_Step_ups_downsample_16_balance_30"
if not os.path.exists("../Plots/{}".format(experiment_name)):
    os.mkdir("../Plots/{}".format(experiment_name))

# %%
comparative_plots_one_vs_all_activity(one_vs_all_activity)

# %%
random_seed = 42
correctness = 'correct'

n_train_subjects = 12
n_validation_subjects = 2

n_time_steps = 38
step = 19
n_features = 3

features = ['accel_x_normalised', 'accel_y_normalised', 'accel_z_normalised']

num_filters = 64
kernel_size = 3
activation = 'relu'
lr = 0.0001
batch_size = 32

epochs = 200

downsample_rate = 16

positive_class_weight = 30.

# %%
losoxv_one_vs_all(experiment_name, one_vs_all_activity, random_seed, correctness,
                 n_train_subjects, n_validation_subjects,
                 n_time_steps, step, n_features,
                 features, num_filters, kernel_size, activation,
                 lr, batch_size, epochs, downsample_rate, positive_class_weight)
# Out:
# Left out subject = adela
# Test subjects = ['aggie', 'andrius', 'diana', 'jack', 'joao', 'nikita', 'rim', 'ron', 'santi', 'seb', 'sharan', 'teo']
# Validation subjects = ['lukasz', 'zoe']
# --------------------------------------------------------------------------------
# Removing outliers
# --------------------------------------------------------------------------------
# Original dataframe length = 117502
# New dataframe length = 116737
# Removed 765 outliers
# Original dataframe length = 8965
# New dataframe length = 8895
# Removed 70 outliers
# --------------------------------------------------------------------------------
# Standardising
# --------------------------------------------------------------------------------
# --------------------------------------------------------------------------------
# Normalising
# --------------------------------------------------------------------------------
# --------------------------------------------------------------------------------
# Generating datasets
# --------------------------------------------------------------------------------
# Total samples for true activity = 1876
# Total samples for false activity = 0
# Training set shapes: X_train = (1876, 38, 3), y_train = (1876, 2)
# Total samples for true activity = 296
# Total samples for false activity = 0
# Valid set shapes: X_valid = (296, 38, 3), y_valid = (296, 2)
# Total samples for true activity = 151
# Total samples for false activity = 0
# Test set shapes: X_test = (151, 38, 3), y_test = (151, 2)
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv1d_1 (Conv1D)            (None, 36, 64)            640
# _________________________________________________________________
# conv1d_2 (Conv1D)            (None, 34, 64)            12352
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 34, 64)            256
# _________________________________________________________________
# conv1d_3 (Conv1D)            (None, 32, 64)            12352
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 2048)              0
# _________________________________________________________________
# dense_1 (Dense)              (None, 100)               204900
# _________________________________________________________________
# dense_2 (Dense)              (None, 2)                 202
# =================================================================
# Total params: 230,702
# Trainable params: 230,574
# Non-trainable params: 128
# _________________________________________________________________
# Train on 1876 samples, validate on 296 samples
# Epoch 1/200
# 1876/1876 [==============================] - 8s 4ms/step - loss: 2.7779 - accuracy: 0.6370 - mse: 0.2296 - val_loss: 0.7102 - val_accuracy: 0.1318 - val_mse: 0.2585
# Epoch 2/200
# 1876/1876 [==============================] - 2s 1ms/step - loss: 2.4277 - accuracy: 0.4851 - mse: 0.2645 - val_loss: 0.7302 - val_accuracy: 0.1115 - val_mse: 0.2685
# Epoch 3/200
# 1876/1876 [==============================] - 2s 1ms/step - loss: 2.1917 - accuracy: 0.4211 - mse: 0.2880 - val_loss: 0.7481 - val_accuracy: 0.1149 - val_mse: 0.2774
# Epoch 4/200
# 1876/1876 [==============================] - 2s 1ms/step - loss: 2.0191 - accuracy: 0.4062 - mse: 0.3035 - val_loss: 0.7649 - val_accuracy: 0.1284 - val_mse: 0.2857
# Epoch 5/200
# 1876/1876 [==============================] - 2s 1ms/step - loss: 1.8865 - accuracy: 0.3987 - mse: 0.3153 - val_loss: 0.7824 - val_accuracy: 0.1554 - val_mse: 0.2943
# Epoch 6/200
# 1876/1876 [==============================] - 2s 1ms/step - loss: 1.7806 - accuracy: 0.4019 - mse: 0.3190 - val_loss: 0.8031 - val_accuracy: 0.1993 - val_mse: 0.3042
# Epoch 7/200
# 1876/1876 [==============================] - 2s 1ms/step - loss: 1.7040 - accuracy: 0.4088 - mse: 0.3240 - val_loss: 0.8219 - val_accuracy: 0.2736 - val_mse: 0.3126
# Epoch 8/200
# 1876/1876 [==============================] - 2s 1ms/step - loss: 1.6227 - accuracy: 0.4216 - mse: 0.3246 - val_loss: 0.8439 - val_accuracy: 0.2872 - val_mse: 0.3217
# Epoch 9/200
# 1876/1876 [==============================] - 2s 983us/step - loss: 1.5611 - accuracy: 0.4414 - mse: 0.3194 - val_loss: 0.8700 - val_accuracy: 0.3277 - val_mse: 0.3312
# Epoch 10/200
# 1876/1876 [==============================] - 2s 1ms/step - loss: 1