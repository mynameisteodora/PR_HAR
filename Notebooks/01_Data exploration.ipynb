# %%
import sys
sys.path.append('..')

from utils.constants import *
from utils.file_readers import *
from utils.data_exploration import *

# %%
df = read_all_files()
# Out:
# 100%|██████████| 304/304 [00:22<00:00, 13.59it/s]

# %%
fig = plot_comparative_histograms(df, activity=0, subjects='all', correctness='incorrect', y_suptitle=1.01)

# %%
fig = plot_comparative_histograms(df, activity=0, subjects=['teo', 'ron', 'adela'], correctness='correct',
                           hspace=0.5, wspace=0.5, y_suptitle=1.02, figsize=(10,5))

# %%
activity_label_dict = get_activity_label_dict()
for i in range(10):
    fig = plot_comparative_histograms(df, activity=i, subjects='all', correctness='correct', y_suptitle=1.01)
    fig.savefig('../Plots/01_Data_exploration/act_{}_{}_comparative_plots.pdf'.format(i, activity_label_dict[i]))

# %% [markdown]
# Create comparative plots for all activities and save them in the Plots folder.

# %%
fig = plot_exercise_duration_boxplot(df, 'correct')

# %%
fig.savefig('../Plots/01_Data_exploration/average_correct_exercise_duration.pdf')

# %%
fig = plot_exercise_duration_boxplot(df, 'incorrect')

# %%
fig.savefig('../Plots/01_Data_exploration/average_incorrect_exercise_duration.pdf')
