# %%
import sys
sys.path.append('..')
import os

from utils.constants import *
from utils.file_readers import *
from utils.data_exploration import *
from utils.signal_processing import *
from utils.sliding_window import *
from utils.stand_norm import *
from utils.one_vs_all_training import *
from utils.experiment_utils import *
# Out:
# Using TensorFlow backend.

# %% [markdown]
# ### Experiment 1 - batch size = 64

# %%
correctness = 'all'

random_seed = 42

n_train_subjects = 12
n_validation_subjects = 2

n_time_steps = 38
step = 19
n_features = 3

features = ['accel_x_normalised', 'accel_y_normalised', 'accel_z_normalised']
features_name = 'normalised'

num_filters = 64
kernel_size = 3
activation = 'relu'

lr = 0.0001
batch_size = 64
epochs = 400

downsample_rate = 16
positive_class_weight = 25.

# %%
activity_names = get_activity_name_dict()
experiment_name = "batch_size_64"

# %%
one_vs_all_activity = 'all'

# %%
print("Activity: {}".format(one_vs_all_activity))
current_experiment_name = "01{}_{}".format(one_vs_all_activity, experiment_name)
print("Current experiment name: {}".format(current_experiment_name))

# create experiment settings
exp_settings = ExperimentSettings(current_experiment_name, one_vs_all_activity, correctness,
                                 random_seed, n_train_subjects, n_validation_subjects,
                                 n_time_steps, step, n_features, features_name,
                                 num_filters, kernel_size, activation, lr,
                                 batch_size, epochs, downsample_rate, positive_class_weight)

# create experiment folder
if not os.path.exists("../Plots/{}".format(current_experiment_name)):
    os.mkdir("../Plots/{}".format(current_experiment_name))

# run experiment
losoxv_stats, cm, histories = losoxv_all(experiment_name=current_experiment_name, random_seed=random_seed, 
                                         correctness=correctness, n_train_subjects=n_train_subjects, 
                                         n_validation_subjects=n_validation_subjects, 
                                         n_time_steps=n_time_steps, step=step, n_features=n_features,
                                         features=features, num_filters=num_filters, kernel_size=kernel_size, 
                                         activation=activation, lr=lr, batch_size=batch_size, epochs=epochs)

# save stats
exp_settings.set_losoxv(losoxv_stats)
exp_settings.set_cm(cm)

exp_settings.save_experiment_stats()

# %% [markdown]
# ### Experiment 2 - more filters

# %%
correctness = 'all'

random_seed = 42

n_train_subjects = 12
n_validation_subjects = 2

n_time_steps = 50
step = 25
n_features = 3

features = ['accel_x_normalised', 'accel_y_normalised', 'accel_z_normalised']
features_name = 'normalised'

num_filters = 128
kernel_size = 3
activation = 'relu'

lr = 0.0001
batch_size = 32
epochs = 400

# %%
activity_names = get_activity_name_dict()
experiment_name = "window_size_50_128_filters"

# %%
one_vs_all_activity = 'all'

# %%
print("Activity: {}".format(one_vs_all_activity))
current_experiment_name = "01{}_{}".format(one_vs_all_activity, experiment_name)
print("Current experiment name: {}".format(current_experiment_name))

# create experiment settings
exp_settings = ExperimentSettings(current_experiment_name, one_vs_all_activity, correctness,
                                 random_seed, n_train_subjects, n_validation_subjects,
                                 n_time_steps, step, n_features, features_name,
                                 num_filters, kernel_size, activation, lr,
                                 batch_size, epochs, downsample_rate=0, positive_class_weight=0)

# create experiment folder
if not os.path.exists("../Plots/{}".format(current_experiment_name)):
    os.mkdir("../Plots/{}".format(current_experiment_name))

# run experiment
losoxv_stats, cm, histories = losoxv_all(experiment_name=current_experiment_name, random_seed=random_seed, 
                                         correctness=correctness, n_train_subjects=n_train_subjects, 
                                         n_validation_subjects=n_validation_subjects, 
                                         n_time_steps=n_time_steps, step=step, n_features=n_features,
                                         features=features, num_filters=num_filters, kernel_size=kernel_size, 
                                         activation=activation, lr=lr, batch_size=batch_size, epochs=epochs)

# save stats
exp_settings.set_losoxv(losoxv_stats)
exp_settings.set_cm(cm)

exp_settings.save_experiment_stats()

# %% [markdown]
# ### Experiment 3 - batch size + more filters

# %%
correctness = 'all'

random_seed = 42

n_train_subjects = 12
n_validation_subjects = 2

n_time_steps = 50
step = 25
n_features = 3

features = ['accel_x_normalised', 'accel_y_normalised', 'accel_z_normalised']
features_name = 'normalised'

num_filters = 128
kernel_size = 3
activation = 'relu'

lr = 0.0001
batch_size = 64
epochs = 400

# %%
activity_names = get_activity_name_dict()
experiment_name = "batch_size_64_128_filters"
one_vs_all_activity = 'all'

# %%
print("Activity: {}".format(one_vs_all_activity))
current_experiment_name = "01{}_{}".format(one_vs_all_activity, experiment_name)
print("Current experiment name: {}".format(current_experiment_name))

# create experiment settings
exp_settings = ExperimentSettings(current_experiment_name, one_vs_all_activity, correctness,
                                 random_seed, n_train_subjects, n_validation_subjects,
                                 n_time_steps, step, n_features, features_name,
                                 num_filters, kernel_size, activation, lr,
                                 batch_size, epochs, downsample_rate=0, positive_class_weight=0)

# create experiment folder
if not os.path.exists("../Plots/{}".format(current_experiment_name)):
    os.mkdir("../Plots/{}".format(current_experiment_name))

# run experiment
losoxv_stats, cm, histories = losoxv_all(experiment_name=current_experiment_name, random_seed=random_seed, 
                                         correctness=correctness, n_train_subjects=n_train_subjects, 
                                         n_validation_subjects=n_validation_subjects, 
                                         n_time_steps=n_time_steps, step=step, n_features=n_features,
                                         features=features, num_filters=num_filters, kernel_size=kernel_size, 
                                         activation=activation, lr=lr, batch_size=batch_size, epochs=epochs)

# save stats
exp_settings.set_losoxv(losoxv_stats)
exp_settings.set_cm(cm)

exp_settings.save_experiment_stats()

# %% [markdown]
# ### Experiment 4 - deeper architecture?

# %%
correctness = 'all'

random_seed = 42

n_train_subjects = 12
n_validation_subjects = 2

n_time_steps = 50
step = 25
n_features = 3

features = ['accel_x_normalised', 'accel_y_normalised', 'accel_z_normalised']
features_name = 'normalised'

num_filters = 128
kernel_size = 3
activation = 'relu'

lr = 0.0001
batch_size = 32
epochs = 400

architecture = 'deep'

# %%
activity_names = get_activity_name_dict()
experiment_name = "batch_size_32_deep_architecture"
one_vs_all_activity = 'all'

# %%
print("Activity: {}".format(one_vs_all_activity))
current_experiment_name = "01{}_{}".format(one_vs_all_activity, experiment_name)
print("Current experiment name: {}".format(current_experiment_name))

# create experiment settings
exp_settings = ExperimentSettings(current_experiment_name, one_vs_all_activity, correctness,
                                 random_seed, n_train_subjects, n_validation_subjects,
                                 n_time_steps, step, n_features, features_name,
                                 num_filters, kernel_size, activation, lr,
                                 batch_size, epochs, downsample_rate=0, positive_class_weight=0)

# create experiment folder
if not os.path.exists("../Plots/{}".format(current_experiment_name)):
    os.mkdir("../Plots/{}".format(current_experiment_name))

# run experiment
losoxv_stats, cm, histories = losoxv_all(experiment_name=current_experiment_name, random_seed=random_seed, 
                                         correctness=correctness, n_train_subjects=n_train_subjects, 
                                         n_validation_subjects=n_validation_subjects, 
                                         n_time_steps=n_time_steps, step=step, n_features=n_features,
                                         features=features, num_filters=num_filters, kernel_size=kernel_size, 
                                         activation=activation, lr=lr, batch_size=batch_size, epochs=epochs,
                                        architecture=architecture)

# save stats
exp_settings.set_losoxv(losoxv_stats)
exp_settings.set_cm(cm)

exp_settings.save_experiment_stats()

# %% [markdown]
# ### Experiment 4 - deeper architecture + larger window size

# %%
correctness = 'all'

random_seed = 42

n_train_subjects = 12
n_validation_subjects = 2

n_time_steps = 75
step = 25
n_features = 3

features = ['accel_x_normalised', 'accel_y_normalised', 'accel_z_normalised']
features_name = 'normalised'

num_filters = 256
kernel_size = 3
activation = 'relu'

lr = 0.0001
batch_size = 32
epochs = 500

architecture = 'deep'

# %%
activity_names = get_activity_name_dict()
experiment_name = "75_time_step_256_filters_deep_architecture"
one_vs_all_activity = 'all'

# %%
print("Activity: {}".format(one_vs_all_activity))
current_experiment_name = "01{}_{}".format(one_vs_all_activity, experiment_name)
print("Current experiment name: {}".format(current_experiment_name))

# create experiment settings
exp_settings = ExperimentSettings(current_experiment_name, one_vs_all_activity, correctness,
                                 random_seed, n_train_subjects, n_validation_subjects,
                                 n_time_steps, step, n_features, features_name,
                                 num_filters, kernel_size, activation, lr,
                                 batch_size, epochs, downsample_rate=0, positive_class_weight=0)

# create experiment folder
if not os.path.exists("../Plots/{}".format(current_experiment_name)):
    os.mkdir("../Plots/{}".format(current_experiment_name))

# run experiment
losoxv_stats, cm, histories = losoxv_all(experiment_name=current_experiment_name, random_seed=random_seed, 
                                         correctness=correctness, n_train_subjects=n_train_subjects, 
                                         n_validation_subjects=n_validation_subjects, 
                                         n_time_steps=n_time_steps, step=step, n_features=n_features,
                                         features=features, num_filters=num_filters, kernel_size=kernel_size, 
                                         activation=activation, lr=lr, batch_size=batch_size, epochs=epochs,
                                        architecture=architecture)

# save stats
exp_settings.set_losoxv(losoxv_stats)
exp_settings.set_cm(cm)

exp_settings.save_experiment_stats()

# %% [markdown]
# ### Experiment 5 - is batchnorm enough to counter the normalisation problem?

# %%
correctness = 'all'

random_seed = 42

n_train_subjects = 12
n_validation_subjects = 2

n_time_steps = 75
step = 25
n_features = 3

features = ['accel_x', 'accel_y', 'accel_z']
features_name = 'raw'

num_filters = 256
kernel_size = 3
activation = 'relu'

lr = 0.0001
batch_size = 32
epochs = 500

architecture = 'batchnorm'

# %%
activity_names = get_activity_name_dict()
experiment_name = "batchnorm_effect_raw_features"
one_vs_all_activity = 'all'

# %%
print("Activity: {}".format(one_vs_all_activity))
current_experiment_name = "01{}_{}".format(one_vs_all_activity, experiment_name)
print("Current experiment name: {}".format(current_experiment_name))

# create experiment settings
exp_settings = ExperimentSettings(current_experiment_name, one_vs_all_activity, correctness,
                                 random_seed, n_train_subjects, n_validation_subjects,
                                 n_time_steps, step, n_features, features_name,
                                 num_filters, kernel_size, activation, lr,
                                 batch_size, epochs, downsample_rate=0, positive_class_weight=0)

# create experiment folder
if not os.path.exists("../Plots/{}".format(current_experiment_name)):
    os.mkdir("../Plots/{}".format(current_experiment_name))

# run experiment
losoxv_stats, cm, histories = losoxv_all(experiment_name=current_experiment_name, random_seed=random_seed, 
                                         correctness=correctness, n_train_subjects=n_train_subjects, 
                                         n_validation_subjects=n_validation_subjects, 
                                         n_time_steps=n_time_steps, step=step, n_features=n_features,
                                         features=features, num_filters=num_filters, kernel_size=kernel_size, 
                                         activation=activation, lr=lr, batch_size=batch_size, epochs=epochs,
                                        architecture=architecture)

# save stats
exp_settings.set_losoxv(losoxv_stats)
exp_settings.set_cm(cm)

exp_settings.save_experiment_stats()
# Out:
# Activity: all
# Current experiment name: 01all_batchnorm_effect_raw_features
# Left out subject = adela
# Test subjects = ['aggie', 'andrius', 'diana', 'jack', 'joao', 'nikita', 'rim', 'ron', 'santi', 'seb', 'sharan', 'teo']
# Validation subjects = ['lukasz', 'zoe']
# --------------------------------------------------------------------------------
# Removing outliers
# --------------------------------------------------------------------------------
# Original dataframe length = 117502
# New dataframe length = 115290
# Removed 2212 outliers
# Original dataframe length = 8965
# New dataframe length = 8749
# Removed 216 outliers
# --------------------------------------------------------------------------------
# Standardising
# --------------------------------------------------------------------------------
# --------------------------------------------------------------------------------
# Normalising
# --------------------------------------------------------------------------------
# ...

# %% [markdown]
# ## Experiment N - pooling layers!

# %%
correctness = 'all'

random_seed = 42

n_train_subjects = 12
n_validation_subjects = 2

n_time_steps = 125
step = 30
n_features = 3

features = ['accel_x_normalised', 'accel_y_normalised', 'accel_z_normalised']
features_name = 'normalised'

num_filters = 256
kernel_size = 5
activation = 'relu'

lr = 0.00001
batch_size = 32
epochs = 200

architecture = 'pooling'
optimiser = 'adam'

downsample_rate = 16
positive_class_weight = 25.

# %%
activity_names = get_activity_name_dict()
experiment_name = "dropout_adam_small_lr_pooling"
one_vs_all_activity = 'all'

# %%
print("Activity: {}".format(one_vs_all_activity))
current_experiment_name = "00{}_{}".format(one_vs_all_activity, experiment_name)
print("Current experiment name: {}".format(current_experiment_name))

# create experiment settings
exp_settings = ExperimentSettings(current_experiment_name, one_vs_all_activity, correctness,
                                 random_seed, n_train_subjects, n_validation_subjects,
                                 n_time_steps, step, n_features, features_name,
                                 num_filters, kernel_size, activation, lr,
                                 batch_size, epochs, downsample_rate=0, positive_class_weight=0)

# create experiment folder
if not os.path.exists("../Plots/{}".format(current_experiment_name)):
    os.mkdir("../Plots/{}".format(current_experiment_name))

# run experiment
losoxv_stats, cm, histories = losoxv_all(experiment_name=current_experiment_name, random_seed=random_seed, 
                                         correctness=correctness, n_train_subjects=n_train_subjects, 
                                         n_validation_subjects=n_validation_subjects, 
                                         n_time_steps=n_time_steps, step=step, n_features=n_features,
                                         features=features, num_filters=num_filters, kernel_size=kernel_size, 
                                         activation=activation, lr=lr, batch_size=batch_size, epochs=epochs,
                                        architecture=architecture, optimiser=optimiser)

# save stats
exp_settings.set_losoxv(losoxv_stats)
exp_settings.set_cm(cm)

exp_settings.save_experiment_stats()
# Out:
# Activity: all
# Current experiment name: 00all_dropout_adam_small_lr_pooling
# Left out subject = adela
# Test subjects = ['aggie', 'andrius', 'diana', 'jack', 'joao', 'nikita', 'rim', 'ron', 'santi', 'seb', 'sharan', 'teo']
# Validation subjects = ['lukasz', 'zoe']
# --------------------------------------------------------------------------------
# Removing outliers
# --------------------------------------------------------------------------------
# Original dataframe length = 117502
# New dataframe length = 115290
# Removed 2212 outliers
# Original dataframe length = 8965
# New dataframe length = 8749
# Removed 216 outliers
# --------------------------------------------------------------------------------
# Standardising
# --------------------------------------------------------------------------------
# --------------------------------------------------------------------------------
# Normalising
# --------------------------------------------------------------------------------
# ...
